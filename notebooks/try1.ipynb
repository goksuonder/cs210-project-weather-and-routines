# %%
import seaborn as sns
import pandas as pd

# %%
import numpy as np

import matplotlib.pyplot as plt

# Generate random data
x = np.random.rand(100)
y = np.random.rand(100)

# Create scatter plot
sns.scatterplot(x=x, y=y)

# Show plot
plt.show()

# %%
df = pd.read_csv('../datas/weather.csv')
df.head()
# Out:
#               name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  Istanbul,Turkey  2024-07-01     30.4     21.0  25.7          30.0
# 1  Istanbul,Turkey  2024-07-02     30.5     21.9  26.3          32.2
# 2  Istanbul,Turkey  2024-07-03     31.5     22.8  26.7          33.4
# 3  Istanbul,Turkey  2024-07-04     27.3     23.2  25.0          28.6
# 4  Istanbul,Turkey  2024-07-05     27.9     20.8  24.4          28.6
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          21.0       25.9  18.6      67.5  ...         17.9      9.0
# 1          21.9       27.1  19.6      68.3  ...         21.6      9.0
# 2          22.8       27.5  18.7      61.9  ...         16.1      9.0
# 3          23.2       25.2  20.2      75.1  ...          5.0      4.0
# 4          20.8       24.5  18.7      71.8  ...         16.5      7.0
#
#    severerisk              sunrise               sunset  moonphase  \
# 0         NaN  2024-07-01T05:35:43  2024-07-01T20:40:14       0.84
# 1         NaN  2024-07-02T05:36:14  2024-07-02T20:40:04       0.87
# 2         NaN  2024-07-03T05:36:46  2024-07-03T20:39:52       0.91
# 3         NaN  2024-07-04T05:37:21  2024-07-04T20:39:39       0.94
# 4         NaN  2024-07-05T05:37:56  2024-07-05T20:39:23       0.98
#
#                conditions                                        description  \
# 0                   Clear               Clear conditions throughout the day.
# 1                   Clear               Clear conditions throughout the day.
# 2        Partially cloudy                  Partly cloudy throughout the day.
# 3  Rain, Partially cloudy        Partly cloudy throughout the day with rain.
# 4  Rain, Partially cloudy  Partly cloudy throughout the day with a chance...
#
#                 icon                                           stations
# 0          clear-day  D8508,LTBA,17063099999,17119099999,17061099999...
# 1          clear-day  D8508,LTBA,17063099999,17119099999,17061099999...
# 2  partly-cloudy-day  17068099999,D8508,LTBA,17063099999,17119099999...
# 3               rain  17068099999,D8508,LTBA,17063099999,17119099999...
# 4               rain  17068099999,D8508,LTBA,17063099999,17119099999...
#
# [5 rows x 33 columns]
